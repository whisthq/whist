# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime
import matplotlib.dates
from tqdm.notebook import tqdm
from IPython.display import display
pd.set_option('mode.chained_assignment', None)

# %%
filename = "log.txt"
df = pd.read_csv(filename, sep="|", header=None)

# %%
df.columns = ["time", "level", "file", "location", "contents"]

# %%
r = df.time.apply(lambda x: ":".join(x.split(":")[:-1]) + "." + x.split(":")[-1])

# %%
df.time = pd.to_datetime(r, errors="coerce")

# %%
cleaned_df = df[df.time.notnull()]

# %%
latency_df = cleaned_df[cleaned_df.contents.str.contains("Latency", na=False, regex=False)]

# %%
s = latency_df.contents.apply(lambda x: x.split(" ")[-1])
latency_df.contents = pd.to_numeric(s, errors="coerce")
latency_df = latency_df[latency_df.contents.notnull()]

# %%
latency_df.sort_values(by=["time"], inplace=True)

# %%
level_to_color = {
    "WARNING": (.5, 0., .5, 0.2), # warnings are purple
    "INFO": (0., .5, .5, 0.2),    # info is cyan
    "ERROR": (1., 0., 0., 0.5)    # errors are red
}

# %%
plt.figure(figsize=(16, 8))
plt.plot(latency_df.time, latency_df.contents, label="Network Latency")
bb = cleaned_df.sort_values(by=["time"])
bb = bb[~bb.contents.str.contains("Latency", regex=False, na=True)]
earliest_time = min(latency_df.time) 
latest_time = max(latency_df.time)
plt.ylim((0.0, 0.050))
for t, l in tqdm(zip(bb.time, bb.level)):
    if earliest_time <= t <= latest_time and l.strip() != "INFO":
        plt.axvline(t, color=level_to_color[l.strip()])
plt.legend(loc='best')
plt.show()
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
def time_in_range(start, end, x):
    """Return true if x is in the range [start, end]"""
    if start <= end:
        return (start <= x) & (x <= end)
    else:
        return (start <= x) | (x <= end)

# %%
a = latency_df[latency_df.contents.diff().abs() > 0.1]
windows = []
for j in range(1+(a.time.diff() >= datetime.timedelta(seconds=1)).cumsum().max()):
    windows.append(a[(a.time.diff() >= datetime.timedelta(seconds=1)).cumsum() == j])
for j in range(len(windows)):
    windows[j] = latency_df[time_in_range(windows[j].time.iloc[0] - datetime.timedelta(seconds=1),
                                          windows[j].time.iloc[-1] + datetime.timedelta(seconds=1),
                                          latency_df.time)]

# %%
for window in windows:
    in_window = time_in_range(window.time.iloc[0], window.time.iloc[-1], cleaned_df.time)
    b = cleaned_df[in_window].sort_values(by=["time"])
    b = b[~b.contents.str.contains("Latency", regex=False, na=True)]
    in_window = time_in_range(window.time.iloc[0], window.time.iloc[-1], latency_df.time)
    plt.figure(figsize=(20, 4))
    plt.gca().xaxis.set_major_formatter(matplotlib.dates.DateFormatter("%H:%M:%S.%f"))
    plt.plot(latency_df[in_window].time, latency_df[in_window].contents, 'o-', color=(0.1, 0.5, 0.6))
    for t, l in zip(b.time, b.level):
        plt.axvline(t, color=level_to_color[l.strip()])
    plt.show()
    display(b)
# Out:
#                         time      level               file  \
# 1602 2020-05-12 21:58:46.413   INFO       video.c
# 1603 2020-05-12 21:58:46.415   INFO       video.c
# 1604 2020-05-12 21:58:46.444   INFO       video.c
# 1605 2020-05-12 21:58:46.446   INFO       main.c
# 1606 2020-05-12 21:58:46.474   INFO       video.c
# 1607 2020-05-12 21:58:46.495   INFO       main.c
# 1608 2020-05-12 21:58:46.517   INFO       video.c
# 1609 2020-05-12 21:58:46.517   INFO       video.c
# 1610 2020-05-12 21:58:46.527   INFO       video.c
# 1611 2020-05-12 21:58:46.527   INFO       video.c
# 1612 2020-05-12 21:58:46.537   INFO       video.c
# 1613 2020-05-12 21:58:46.537   INFO       video.c
# 1614 2020-05-12 21:58:46.547   INFO       video.c
# 1615 2020-05-12 21:58:46.547   INFO       video.c
# 1617 2020-05-12 21:58:46.556   INFO       video.c
# 1616 2020-05-12 21:58:46.556   INFO       video.c
# 1618 2020-05-12 21:58:46.565   INFO       video.c
# 1619 2020-05-12 21:58:46.565   INFO       video.c
# 1620 2020-05-12 21:58:46.575   INFO       video.c
# 1621 2020-05-12 21:58:46.575   INFO       video.c
# 1622 2020-05-12 21:58:46.585   INFO       video.c
# 1623 2020-05-12 21:58:46.585   INFO       video.c
# 1624 2020-05-12 21:58:46.593   INFO       video.c
# 1625 2020-05-12 21:58:46.593   INFO       video.c
# 1626 2020-05-12 21:58:46.602   INFO       video.c
# 1627 2020-05-12 21:58:46.602   INFO       video.c
# 1628 2020-05-12 21:58:46.611   INFO       video.c
# 1629 2020-05-12 21:58:46.611   INFO       video.c
# 1630 2020-05-12 21:58:46.620   INFO       video.c
# 1631 2020-05-12 21:58:46.620   INFO       video.c
# ...                      ...        ...                ...
# 1825 2020-05-12 21:58:47.449   INFO       video.c
# 1826 2020-05-12 21:58:47.449   INFO       video.c
# 1827 2020-05-12 21:58:47.450   INFO       video.c
# 1828 2020-05-12 21:58:47.452   INFO       video.c
# 1829 2020-05-12 21:58:47.452   INFO       video.c
# 1830 2020-05-12 21:58:47.452   INFO       video.c
# 1831 2020-05-12 21:58:47.456   INFO       video.c
# 1832 2020-05-12 21:58:47.457   INFO       video.c
# 1833 2020-05-12 21:58:47.458   INFO       video.c
# 1834 2020-05-12 21:58:47.459   INFO       video.c
# 1835 2020-05-12 21:58:47.460   INFO       video.c
# 1836 2020-05-12 21:58:47.464   INFO       video.c
# 1837 2020-05-12 21:58:47.464   INFO       video.c
# 1838 2020-05-12 21:58:47.464   INFO       video.c
# 1839 2020-05-12 21:58:47.465   INFO       video.c
# 1841 2020-05-12 21:58:47.468   INFO       video.c
# 1840 2020-05-12 21:58:47.468   INFO       video.c
# 1842 2020-05-12 21:58:47.476   INFO       video.c
# 1843 2020-05-12 21:58:47.521   INFO       main.c
# 1844 2020-05-12 21:58:47.661   INFO       audio.c
# 1845 2020-05-12 21:58:47.684   INFO       main.c
# 1846 2020-05-12 21:58:47.703   INFO       audio.c
# 1847 2020-05-12 21:58:47.717   INFO       video.c
# 1848 2020-05-12 21:58:47.729   INFO       video.c
# 1849 2020-05-12 21:58:47.731   INFO       video.c
# 1850 2020-05-12 21:58:47.744   INFO       video.c
# 1851 2020-05-12 21:58:47.776   INFO       main.c
# 1852 2020-05-12 21:58:47.796   INFO       video.c
# 1853 2020-05-12 21:58:47.796   INFO       video.c
# 1854 2020-05-12 21:58:47.802   INFO       video.c
#
#                   location                                           contents
# 1602     ReceiveVideo:706    NACK for Video ID 1441, Index 10 Received! Bu...
# 1603     RenderScreen:226    Late! Rendering ID 1442 (Age 0.031652) (Packe...
# 1604     RenderScreen:226    Late! Rendering ID 1443 (Age 0.043244) (Packe...
# 1605   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 1606     RenderScreen:226    Late! Rendering ID 1444 (Age 0.027657) (Packe...
# 1607   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 1608      updateVideo:621    ************NACKING VIDEO PACKET 1445 15 (/28...
# 1609             nack:126    Missing Video Packet ID 1445 Index 15, NACKin...
# 1610      updateVideo:621    ************NACKING VIDEO PACKET 1445 16 (/28...
# 1611             nack:126    Missing Video Packet ID 1445 Index 16, NACKin...
# 1612      updateVideo:621    ************NACKING VIDEO PACKET 1445 17 (/28...
# 1613             nack:126    Missing Video Packet ID 1445 Index 17, NACKin...
# 1614      updateVideo:621    ************NACKING VIDEO PACKET 1445 18 (/28...
# 1615             nack:126    Missing Video Packet ID 1445 Index 18, NACKin...
# 1617             nack:126    Missing Video Packet ID 1445 Index 19, NACKin...
# 1616      updateVideo:621    ************NACKING VIDEO PACKET 1445 19 (/28...
# 1618      updateVideo:621    ************NACKING VIDEO PACKET 1445 20 (/28...
# 1619             nack:126    Missing Video Packet ID 1445 Index 20, NACKin...
# 1620      updateVideo:621    ************NACKING VIDEO PACKET 1445 21 (/28...
# 1621             nack:126    Missing Video Packet ID 1445 Index 21, NACKin...
# 1622      updateVideo:621    ************NACKING VIDEO PACKET 1445 22 (/28...
# 1623             nack:126    Missing Video Packet ID 1445 Index 22, NACKin...
# 1624      updateVideo:621    ************NACKING VIDEO PACKET 1445 23 (/28...
# 1625             nack:126    Missing Video Packet ID 1445 Index 23, NACKin...
# 1626      updateVideo:621    ************NACKING VIDEO PACKET 1445 24 (/28...
# 1627             nack:126    Missing Video Packet ID 1445 Index 24, NACKin...
# 1628      updateVideo:621    ************NACKING VIDEO PACKET 1445 25 (/28...
# 1629             nack:126    Missing Video Packet ID 1445 Index 25, NACKin...
# 1630      updateVideo:621    ************NACKING VIDEO PACKET 1445 26 (/28...
# 1631             nack:126    Missing Video Packet ID 1445 Index 26, NACKin...
# ...                    ...                                                ...
# 1825      updateVideo:598                                    Skip this render
# 1826     ReceiveVideo:706    NACK for Video ID 1463, Index 11 Received! Bu...
# 1827     RenderScreen:226    Late! Rendering ID 1464 (Age 0.025694) (Packe...
# 1828     ReceiveVideo:706    NACK for Video ID 1463, Index 12 Received! Bu...
# 1829     ReceiveVideo:706    NACK for Video ID 1463, Index 13 Received! Bu...
# 1830     ReceiveVideo:706    NACK for Video ID 1463, Index 14 Received! Bu...
# 1831     ReceiveVideo:706    NACK for Video ID 1463, Index 15 Received! Bu...
# 1832     ReceiveVideo:706    NACK for Video ID 1463, Index 16 Received! Bu...
# 1833     ReceiveVideo:706    NACK for Video ID 1463, Index 17 Received! Bu...
# 1834     ReceiveVideo:706    NACK for Video ID 1463, Index 18 Received! Bu...
# 1835     ReceiveVideo:706    NACK for Video ID 1463, Index 19 Received! Bu...
# 1836      updateVideo:598                                    Skip this render
# 1837     ReceiveVideo:706    NACK for Video ID 1463, Index 20 Received! Bu...
# 1838     RenderScreen:226    Late! Rendering ID 1465 (Age 0.036633) (Packe...
# 1839     ReceiveVideo:706    NACK for Video ID 1463, Index 21 Received! Bu...
# 1841     ReceiveVideo:706    NACK for Video ID 1463, Index 23 Received! Bu...
# 1840     ReceiveVideo:706    NACK for Video ID 1463, Index 22 Received! Bu...
# 1842     RenderScreen:226    Late! Rendering ID 1466 (Age 0.039757) (Packe...
# 1843   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 1844      updateAudio:126      Audio Queue too low: 13302. Needs to catch up!
# 1845   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 1846      updateAudio:135                Done catching up! Audio Queue: 29407
# 1847      updateVideo:598                                    Skip this render
# 1848      updateVideo:598                                    Skip this render
# 1849     RenderScreen:226    Late! Rendering ID 1471 (Age 0.033172) (Packe...
# 1850     RenderScreen:226    Late! Rendering ID 1472 (Age 0.028070) (Packe...
# 1851           update:212                                           Ping! 149
# 1852      updateVideo:621    ************NACKING VIDEO PACKET 1474 8 (/17)...
# 1853             nack:126    Missing Video Packet ID 1474 Index 8, NACKing...
# 1854     ReceiveVideo:712    Received the original Video ID 1474 Index 8, ...
#
# [251 rows x 5 columns]
#                         time      level               file  \
# 2389 2020-05-12 21:58:55.911   INFO       audio.c
# 2390 2020-05-12 21:58:55.916   INFO       video.c
# 2391 2020-05-12 21:58:55.918   INFO       video.c
# 2392 2020-05-12 21:58:55.932   INFO       video.c
# 2393 2020-05-12 21:58:55.971   WARNING    audio.c
# 2394 2020-05-12 21:58:56.004   WARNING    audio.c
# 2395 2020-05-12 21:58:56.007   INFO       video.c
# 2396 2020-05-12 21:58:56.025   WARNING    audio.c
# 2397 2020-05-12 21:58:56.072   INFO       audio.c
# 2398 2020-05-12 21:58:56.142   INFO       main.c
# 2399 2020-05-12 21:58:56.152   INFO       audio.c
# 2400 2020-05-12 21:58:56.164   INFO       video.c
# 2401 2020-05-12 21:58:56.177   INFO       video.c
# 2402 2020-05-12 21:58:56.178   INFO       video.c
# 2403 2020-05-12 21:58:56.255   INFO       video.c
# 2404 2020-05-12 21:58:56.290   INFO       main.c
# 2405 2020-05-12 21:58:56.407   INFO       main.c
# 2406 2020-05-12 21:58:56.412   INFO       audio.c
# 2407 2020-05-12 21:58:56.416   INFO       audio.c
# 2409 2020-05-12 21:58:56.441   INFO       video.c
# 2410 2020-05-12 21:58:56.442   INFO       video.c
# 2411 2020-05-12 21:58:56.451   INFO       video.c
# 2412 2020-05-12 21:58:56.452   INFO       video.c
# 2413 2020-05-12 21:58:56.464   INFO       video.c
# 2414 2020-05-12 21:58:56.563   INFO       video.c
# 2415 2020-05-12 21:58:56.563   INFO       video.c
# 2416 2020-05-12 21:58:56.572   INFO       video.c
# 2417 2020-05-12 21:58:56.572   INFO       video.c
# 2419 2020-05-12 21:58:56.581   INFO       video.c
# 2418 2020-05-12 21:58:56.581   INFO       video.c
# ...                      ...        ...                ...
# 2617 2020-05-12 21:58:57.472   INFO       video.c
# 2613 2020-05-12 21:58:57.472   INFO       video.c
# 2615 2020-05-12 21:58:57.472   INFO       video.c
# 2614 2020-05-12 21:58:57.472   INFO       video.c
# 2616 2020-05-12 21:58:57.472   INFO       video.c
# 2612 2020-05-12 21:58:57.472   INFO       video.c
# 2621 2020-05-12 21:58:57.473   INFO       video.c
# 2622 2020-05-12 21:58:57.473   INFO       video.c
# 2623 2020-05-12 21:58:57.473   INFO       video.c
# 2624 2020-05-12 21:58:57.477   INFO       audio.c
# 2625 2020-05-12 21:58:57.478   INFO       video.c
# 2626 2020-05-12 21:58:57.496   INFO       video.c
# 2627 2020-05-12 21:58:57.499   INFO       video.c
# 2628 2020-05-12 21:58:57.500   INFO       video.c
# 2629 2020-05-12 21:58:57.503   INFO       video.c
# 2630 2020-05-12 21:58:57.505   INFO       video.c
# 2631 2020-05-12 21:58:57.508   INFO       video.c
# 2632 2020-05-12 21:58:57.510   INFO       video.c
# 2633 2020-05-12 21:58:57.510   INFO       video.c
# 2634 2020-05-12 21:58:57.512   INFO       video.c
# 2635 2020-05-12 21:58:57.515   INFO       video.c
# 2636 2020-05-12 21:58:57.516   INFO       video.c
# 2637 2020-05-12 21:58:57.517   INFO       video.c
# 2638 2020-05-12 21:58:57.519   INFO       video.c
# 2639 2020-05-12 21:58:57.597   INFO       main.c
# 2640 2020-05-12 21:58:57.628   INFO       main.c
# 2641 2020-05-12 21:58:57.671   INFO       audio.c
# 2642 2020-05-12 21:58:57.677   INFO       main.c
# 2643 2020-05-12 21:58:57.792   INFO       main.c
# 2644 2020-05-12 21:58:57.792   INFO       main.c
#
#                   location                                           contents
# 2389      updateAudio:135                Done catching up! Audio Queue: 28240
# 2390      updateVideo:598                                    Skip this render
# 2391     RenderScreen:226    Late! Rendering ID 1649 (Age 0.030412) (Packe...
# 2392     RenderScreen:226    Late! Rendering ID 1650 (Age 0.038453) (Packe...
# 2393      updateAudio:174    Audio queue full, skipping ID 3416 (Queued: 6...
# 2394      updateAudio:174    Audio queue full, skipping ID 3417 (Queued: 4...
# 2395     RenderScreen:226    Late! Rendering ID 1652 (Age 0.027096) (Packe...
# 2396      updateAudio:174    Audio queue full, skipping ID 3418 (Queued: 3...
# 2397      updateAudio:126      Audio Queue too low: 10998. Needs to catch up!
# 2398   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 2399      updateAudio:135                Done catching up! Audio Queue: 29008
# 2400      updateVideo:598                                    Skip this render
# 2401      updateVideo:598                                    Skip this render
# 2402     RenderScreen:226    Late! Rendering ID 1655 (Age 0.027230) (Packe...
# 2403     RenderScreen:226    Late! Rendering ID 1658 (Age 0.026114) (Packe...
# 2404           update:212                                           Ping! 166
# 2405   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 2406      updateAudio:126      Audio Queue too low: 15350. Needs to catch up!
# 2407      updateAudio:135                Done catching up! Audio Queue: 30657
# 2409      updateVideo:598                                    Skip this render
# 2410     RenderScreen:226    Late! Rendering ID 1661 (Age 0.029245) (Packe...
# 2411      updateVideo:598                                    Skip this render
# 2412     RenderScreen:226    Late! Rendering ID 1662 (Age 0.036098) (Packe...
# 2413     RenderScreen:226    Late! Rendering ID 1663 (Age 0.036534) (Packe...
# 2414      updateVideo:621    ************NACKING VIDEO PACKET 1666 18 (/26...
# 2415             nack:126    Missing Video Packet ID 1666 Index 18, NACKin...
# 2416      updateVideo:621    ************NACKING VIDEO PACKET 1666 19 (/26...
# 2417             nack:126    Missing Video Packet ID 1666 Index 19, NACKin...
# 2419             nack:126    Missing Video Packet ID 1666 Index 20, NACKin...
# 2418      updateVideo:621    ************NACKING VIDEO PACKET 1666 20 (/26...
# ...                    ...                                                ...
# 2617     ReceiveVideo:712    Received the original Video ID 1683 Index 11,...
# 2613     ReceiveVideo:712    Received the original Video ID 1683 Index 7, ...
# 2615     ReceiveVideo:712    Received the original Video ID 1683 Index 9, ...
# 2614     ReceiveVideo:712    Received the original Video ID 1683 Index 8, ...
# 2616     ReceiveVideo:712    Received the original Video ID 1683 Index 10,...
# 2612     ReceiveVideo:712    Received the original Video ID 1683 Index 6, ...
# 2621     ReceiveVideo:712    Received the original Video ID 1683 Index 15,...
# 2622     ReceiveVideo:712    Received the original Video ID 1683 Index 16,...
# 2623     ReceiveVideo:712    Received the original Video ID 1683 Index 17,...
# 2624      updateAudio:135                Done catching up! Audio Queue: 29008
# 2625     RenderScreen:226    Late! Rendering ID 1683 (Age 0.130359) (Packe...
# 2626     ReceiveVideo:706    NACK for Video ID 1683, Index 5 Received! But...
# 2627     ReceiveVideo:706    NACK for Video ID 1683, Index 6 Received! But...
# 2628     ReceiveVideo:706    NACK for Video ID 1683, Index 7 Received! But...
# 2629     ReceiveVideo:706    NACK for Video ID 1683, Index 8 Received! But...
# 2630     ReceiveVideo:706    NACK for Video ID 1683, Index 9 Received! But...
# 2631     ReceiveVideo:706    NACK for Video ID 1683, Index 10 Received! Bu...
# 2632     ReceiveVideo:706    NACK for Video ID 1683, Index 11 Received! Bu...
# 2633     ReceiveVideo:706    NACK for Video ID 1683, Index 12 Received! Bu...
# 2634     ReceiveVideo:706    NACK for Video ID 1683, Index 13 Received! Bu...
# 2635     ReceiveVideo:706    NACK for Video ID 1683, Index 14 Received! Bu...
# 2636     ReceiveVideo:706    NACK for Video ID 1683, Index 15 Received! Bu...
# 2637     ReceiveVideo:706    NACK for Video ID 1683, Index 16 Received! Bu...
# 2638     ReceiveVideo:706    NACK for Video ID 1683, Index 17 Received! Bu...
# 2639   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 2640   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 2641      updateAudio:126      Audio Queue too low: 13302. Needs to catch up!
# 2642   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 2643   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 2644           update:212                                           Ping! 169
#
# [253 rows x 5 columns]
#                         time      level               file  \
# 3162 2020-05-12 21:59:22.413   INFO       main.c
# 3163 2020-05-12 21:59:22.490   INFO       video.c
# 3164 2020-05-12 21:59:22.832   INFO       main.c
# 3165 2020-05-12 21:59:22.856   WARNING    network.c
# 3166 2020-05-12 21:59:22.983   INFO       main.c
# 3167 2020-05-12 21:59:23.045   INFO       main.c
# 3169 2020-05-12 21:59:23.055   INFO       video.c
# 3168 2020-05-12 21:59:23.055   INFO       video.c
# 3170 2020-05-12 21:59:23.063   INFO       video.c
# 3171 2020-05-12 21:59:23.063   INFO       video.c
# 3173 2020-05-12 21:59:23.070   INFO       video.c
# 3174 2020-05-12 21:59:23.072   INFO       video.c
# 3175 2020-05-12 21:59:23.081   INFO       video.c
# 3176 2020-05-12 21:59:23.088   INFO       video.c
# 3177 2020-05-12 21:59:23.090   INFO       video.c
# 3178 2020-05-12 21:59:23.203   INFO       main.c
# 3179 2020-05-12 21:59:23.237   INFO       video.c
# 3180 2020-05-12 21:59:23.333   INFO       main.c
# 3182 2020-05-12 21:59:23.412   INFO       video.c
# 3183 2020-05-12 21:59:23.473   INFO       main.c
# 3193 2020-05-12 21:59:23.678   INFO       main.c
# 3192 2020-05-12 21:59:23.678   INFO       main.c
# 3191 2020-05-12 21:59:23.678   INFO       main.c
# 3190 2020-05-12 21:59:23.678   INFO       main.c
# 3189 2020-05-12 21:59:23.678   INFO       main.c
# 3187 2020-05-12 21:59:23.678   INFO       main.c
# 3186 2020-05-12 21:59:23.678   INFO       main.c
# 3185 2020-05-12 21:59:23.678   INFO       main.c
# 3184 2020-05-12 21:59:23.678   INFO       main.c
# 3188 2020-05-12 21:59:23.678   INFO       main.c
# 3194 2020-05-12 21:59:23.766   INFO       main.c
# 3195 2020-05-12 21:59:23.835   INFO       main.c
#
#                   location                                           contents
# 3162   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 3163     RenderScreen:226    Late! Rendering ID 2176 (Age 0.028051) (Packe...
# 3164           update:212                                           Ping! 219
# 3165    ReadUDPPacket:358                        Unexpected Packet Error: 997
# 3166   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 3167           update:212                                           Ping! 219
# 3169             nack:126    Missing Video Packet ID 2189 Index 5, NACKing...
# 3168      updateVideo:621    ************NACKING VIDEO PACKET 2189 5 (/35)...
# 3170      updateVideo:621    ************NACKING VIDEO PACKET 2189 6 (/35)...
# 3171             nack:126    Missing Video Packet ID 2189 Index 6, NACKing...
# 3173     ReceiveVideo:712    Received the original Video ID 2189 Index 5, ...
# 3174     ReceiveVideo:712    Received the original Video ID 2189 Index 6, ...
# 3175     ReceiveVideo:706    NACK for Video ID 2189, Index 5 Received! But...
# 3176     ReceiveVideo:706    NACK for Video ID 2189, Index 6 Received! But...
# 3177     RenderScreen:226    Late! Rendering ID 2189 (Age 0.047493) (Packe...
# 3178   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 3179     RenderScreen:226    Late! Rendering ID 2192 (Age 0.026244) (Packe...
# 3180           update:212                                           Ping! 220
# 3182     RenderScreen:226    Late! Rendering ID 2196 (Age 0.033109) (Packe...
# 3183   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 3193   ReceivePackets:309                              message_time: 0.008775
# 3192   ReceivePackets:308                            max_audio_time: 0.000022
# 3191   ReceivePackets:307                                audio_time: 0.002488
# 3190   ReceivePackets:306                            max_video_time: 0.000813
# 3189   ReceivePackets:305                                video_time: 0.100337
# 3187   ReceivePackets:303                         update_audio_time: 1.191856
# 3186   ReceivePackets:302                         update_video_time: 0.135389
# 3185   ReceivePackets:301                           recvfrom_time: 101.253640
# 3184   ReceivePackets:300                                world_time: 5.001358
# 3188   ReceivePackets:304                                 hash_time: 0.000000
# 3194   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 3195           update:212                                           Ping! 221
#                         time      level               file  \
# 3591 2020-05-12 21:59:57.498   INFO       main.c
# 3592 2020-05-12 21:59:57.641   INFO       main.c
# 3593 2020-05-12 21:59:57.675   INFO       video.c
# 3594 2020-05-12 21:59:57.891   INFO       main.c
# 3595 2020-05-12 21:59:58.104   INFO       main.c
# 3597 2020-05-12 21:59:58.148   INFO       video.c
# 3598 2020-05-12 21:59:58.148   INFO       video.c
# 3599 2020-05-12 21:59:58.148   INFO       video.c
# 3600 2020-05-12 21:59:58.149   INFO       main.c
# 3601 2020-05-12 21:59:58.218   INFO       main.c
# 3602 2020-05-12 21:59:58.393   INFO       main.c
# 3604 2020-05-12 21:59:58.489   INFO       main.c
# 3605 2020-05-12 21:59:58.683   INFO       main.c
# 3606 2020-05-12 21:59:58.683   INFO       main.c
# 3607 2020-05-12 21:59:58.683   INFO       main.c
# 3608 2020-05-12 21:59:58.683   INFO       main.c
# 3609 2020-05-12 21:59:58.683   INFO       main.c
# 3610 2020-05-12 21:59:58.683   INFO       main.c
# 3611 2020-05-12 21:59:58.683   INFO       main.c
# 3612 2020-05-12 21:59:58.683   INFO       main.c
# 3613 2020-05-12 21:59:58.683   INFO       main.c
# 3614 2020-05-12 21:59:58.683   INFO       main.c
# 3615 2020-05-12 21:59:58.893   INFO       main.c
# 3617 2020-05-12 21:59:59.099   INFO       main.c
# 3618 2020-05-12 21:59:59.393   INFO       main.c
#
#                   location                                           contents
# 3591   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 3592   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 3593     RenderScreen:226    Late! Rendering ID 2981 (Age 0.033576) (Packe...
# 3594           update:212                                           Ping! 289
# 3595           update:212                                           Ping! 289
# 3597      updateVideo:497                      MBPS: 25208483.840444 0.333289
# 3598      updateVideo:529                              MBPS2: 25838695.936455
# 3599      updateVideo:535                                     MBPS3: 25750000
# 3600           update:161              Asking for server MBPS to be 24.557114
# 3601   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 3602           update:212                                           Ping! 290
# 3604   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 3605   ReceivePackets:300                                world_time: 5.000890
# 3606   ReceivePackets:301                           recvfrom_time: 133.437170
# 3607   ReceivePackets:302                         update_video_time: 0.171777
# 3608   ReceivePackets:303                         update_audio_time: 1.650046
# 3609   ReceivePackets:304                                 hash_time: 0.000000
# 3610   ReceivePackets:305                                video_time: 0.126867
# 3611   ReceivePackets:306                            max_video_time: 0.001338
# 3612   ReceivePackets:307                                audio_time: 0.003495
# 3613   ReceivePackets:308                            max_audio_time: 0.000022
# 3614   ReceivePackets:309                              message_time: 0.011682
# 3615           update:212                                           Ping! 291
# 3617   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 3618           update:212                                           Ping! 292
#                         time      level               file  \
# 3991 2020-05-12 22:00:28.005   INFO       main.c
# 3992 2020-05-12 22:00:28.156   INFO       video.c
# 3993 2020-05-12 22:00:28.156   INFO       video.c
# 3994 2020-05-12 22:00:28.156   INFO       video.c
# 3995 2020-05-12 22:00:28.158   INFO       main.c
# 3996 2020-05-12 22:00:28.233   INFO       video.c
# 3997 2020-05-12 22:00:28.325   INFO       main.c
# 3998 2020-05-12 22:00:28.443   INFO       main.c
# 3999 2020-05-12 22:00:28.500   INFO       main.c
# 4000 2020-05-12 22:00:28.645   INFO       main.c
# 4001 2020-05-12 22:00:28.654   INFO       main.c
# 4012 2020-05-12 22:00:28.689   INFO       main.c
# 4011 2020-05-12 22:00:28.689   INFO       main.c
# 4010 2020-05-12 22:00:28.689   INFO       main.c
# 4009 2020-05-12 22:00:28.689   INFO       main.c
# 4008 2020-05-12 22:00:28.689   INFO       main.c
# 4006 2020-05-12 22:00:28.689   INFO       main.c
# 4005 2020-05-12 22:00:28.689   INFO       main.c
# 4004 2020-05-12 22:00:28.689   INFO       main.c
# 4003 2020-05-12 22:00:28.689   INFO       main.c
# 4007 2020-05-12 22:00:28.689   INFO       main.c
# 4013 2020-05-12 22:00:28.692   INFO       video.c
# 4014 2020-05-12 22:00:28.791   INFO       main.c
# 4015 2020-05-12 22:00:28.875   INFO       main.c
# 4016 2020-05-12 22:00:28.944   INFO       main.c
# 4018 2020-05-12 22:00:29.065   INFO       main.c
# 4019 2020-05-12 22:00:29.285   INFO       main.c
# 4020 2020-05-12 22:00:29.444   INFO       main.c
# 4021 2020-05-12 22:00:29.456   INFO       main.c
#
#                   location                                           contents
# 3991   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 3992      updateVideo:497                      MBPS: 31457280.000000 0.333321
# 3993      updateVideo:529                              MBPS2: 31457280.000000
# 3994      updateVideo:535                                     MBPS3: 31250000
# 3995           update:161              Asking for server MBPS to be 29.802322
# 3996     RenderScreen:226    Late! Rendering ID 3660 (Age 0.026341) (Packe...
# 3997   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 3998           update:212                                           Ping! 350
# 3999   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 4000   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 4001           update:212                                           Ping! 350
# 4012   ReceivePackets:309                              message_time: 0.014628
# 4011   ReceivePackets:308                            max_audio_time: 0.000293
# 4010   ReceivePackets:307                                audio_time: 0.004741
# 4009   ReceivePackets:306                            max_video_time: 0.001338
# 4008   ReceivePackets:305                                video_time: 0.146947
# 4006   ReceivePackets:303                         update_audio_time: 2.031863
# 4005   ReceivePackets:302                         update_video_time: 0.202928
# 4004   ReceivePackets:301                           recvfrom_time: 161.036645
# 4003   ReceivePackets:300                                world_time: 5.000187
# 4007   ReceivePackets:304                                 hash_time: 0.000000
# 4013     RenderScreen:226    Late! Rendering ID 3670 (Age 0.035971) (Packe...
# 4014   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 4015   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 4016           update:212                                           Ping! 351
# 4018   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 4019   ReceivePackets:369    Took more than 20ms to receive something!! To...
# 4020           update:212                                           Ping! 352
# 4021   ReceivePackets:369    Took more than 20ms to receive something!! To...
