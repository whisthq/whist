# %%
import names
import numpy as np
import random
from ProductHuntScraper import ProductHunt
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import random

# %%
def initialize_db():
    cred = credentials.Certificate("new-website-prod-firebase-adminsdk-lni3g-ecda7ac2fe.json")
    firebase_admin.initialize_app(cred)
    db = firestore.client()
    return db

# %%
db = initialize_db()

# %%
def generate_keys_firebase():
    users_ref = db.collection(u'waitlist')
    docs = users_ref.stream()
    cache = {}
    for doc in docs:
        cache[doc.id] = 1
    return cache

# %%
def write_to_firebase(fake_people_and_their_points):
    cache = generate_keys_firebase()
    points_list = {}
    for user_info in fake_people_and_their_points:
        rand_int = random.randint(1,1000000)
        email = "generated_people{rand_int}@gmail.com".format(rand_int=str(rand_int))
        while email in cache:
            rand_int = random.randint(1,1000000)
            email = "generated_people{rand_int}@gmail.com".format(rand_int=str(rand_int))
            print(email)
        doc_ref = db.collection(u'waitlist').document(email)
        doc_ref.set({
            u'name': user_info['person_name'],
            u'referrals': int(user_info['person_referrals']),
            u'points': int(user_info['person_points'])
        })
        points_list[email] = {"email": email, "points": int(user_info['person_points']), "name": user_info['person_name'], "referrals": int(user_info['person_referrals'])}
        
    leaderboard_ref = db.collection(u'metadata').document(u'waitlist').update({
        u'leaderboard': points_list
    })

# %%
def write_to_firebase(fake_people_and_their_points):
    cache = generate_keys_firebase()
    points_dict = {}
    for user_info in fake_people_and_their_points:
        rand_int = random.randint(1,1000000)
        email = "generated_people{rand_int}@gmail.com".format(rand_int=str(rand_int))
        while email in cache:
            rand_int = random.randint(1,1000000)
            email = "generated_people{rand_int}@gmail.com".format(rand_int=str(rand_int))
            print(email)
#         doc_ref = db.collection(u'waitlist').document(email)
#         doc_ref.set({
#             u'name': user_info['person_name'],
#             u'referrals': int(user_info['person_referrals']),
#             u'points': int(user_info['person_points'])
#         })
        points_dict[email] = {"email": email, "points": int(user_info['person_points']), "name": user_info['person_name'], "referrals": int(user_info['person_referrals'])}
        
    leaderboard_ref = db.collection(u'metadata').document(u'waitlist').update({
        u'leaderboard': points_dict
    })

# %%
def generate_right_skewed_distribution(max_number_referrals):
    ''' takes in the ceiling of random referrals (max_number_referrals)
    and returns a right-skewed distribution up to max_number_referrals
    and its corresponding array. Input a value greater than 2. 
    '''
    pers = np.arange(0,max_number_referrals,1)

    prob = [10000] * (0) + [9.0]* (1) + [1.0] * (len(pers) - 1)
    prob /= np.sum(prob)
    return pers, prob

# %%
def generate_name_with_typo_sometimes(percentage):
    '''generate the name with some typos some percentage of the time'''
    name = names.get_full_name()
    typo_rand = random.randint(1, 100)
    if typo_rand <= percentage:
        name_len = len(name)
        introduce_typo_location = random.randint(0, name_len)
        error_type = random.randint(1,2)
        if error_type == 1:
            first_last = random.randint(1,2)
            typo_name = lower_nth(name, first_last)
        else:
            typo_name = capitalize_nth(name, introduce_typo_location)
        return typo_name
    return name

# %%
def lower_nth(s, n):
    return s[:n] + s[n:].lower()

# %%
def capitalize_nth(s, n):
    return s[:n] + s[n:].capitalize()

# %%
def generate_from_names_library(number_gen, max_number_referrals):
    '''generate a list of names up to number_gen people with each 
    referral maxed out at max_number_referrals using the names library
    '''
    pers, right_distribution = generate_right_skewed_distribution(max_number_referrals)
    people = set()
    people_referrals = []
    
    while len(people) != number_gen:
        name = generate_name_with_typo_sometimes(80)
        if random.randint(0, 10) < 7:
            name = name.split(" ")[0]
        people.add(name)            
    for person in people:
        number = np.random.choice(pers, 1, p=right_distribution)[0]
        people_referrals.append((person, number))
        
    return people_referrals

# %%
def generate_from_names_product_hunt(number_gen, max_number_referrals):
    '''generate a list of names up to number_gen people with each 
    referral maxed out at max_number_referrals by scraping ProductHunt
    '''
    
    PH = ProductHunt()
    makers, hunters = PH.find_makers_and_hunters()
    pers, right_distribution = generate_right_skewed_distribution(max_number_referrals)
    people = set()
    people_referrals = []

    people.update(makers)
    people.update(hunters)
    
    while len(people) < number_gen:
        name = generate_name_with_typo_sometimes(20)
        people.add(name)
    
    for person in people:
        if len(people_referrals) == number_gen:
            break
        number = np.random.choice(pers, 1, p = right_distribution)[0]
        people_referrals.append((person, number))
        
    return people_referrals

# %%
def generate_fake_points_people(people_referrals):
    '''
    takes in a tuples of (names, referrals) and generates their 
    point allocation
    '''
    
    all_peoples_data = []
    for people_referral in people_referrals:
#         pers, distribution = generate_fake_points_distribution(people_referral[1], max_points)
#         number = np.random.choice(pers, 1, p = distribution)[0]
        name = people_referral[0]
        num_referrals = people_referral[1]
        points = num_referrals * 100 + 50
        person_data = {
            'person_name': name,
            'person_referrals': num_referrals,
            'person_points': points + np.random.normal(20, 8, 1)[0]
        }
        all_peoples_data.append(person_data)
        
    return all_peoples_data

# %%
# print("generating refs")
# refs = generate_from_names_library(5007, 15)
# print("generating people")
# fake_people = generate_fake_points_people(refs)
# print("writing")
write_to_firebase(fake_people[0:1000])
print("done")
# Out:
# done

# %%
from firebase_admin import firestore

db.collection(u'metadata').document(u'waitlist').update(
  'leaderboard', Firestore.FieldValue.arrayUnion({"email": "new_email", "points": 100})
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-fd55d16f8859> in <module>
#       2
#       3 db.collection(u'metadata').document(u'waitlist').update(
# ----> 4   'leaderboard', firestore.fieldValue.arrayUnion({"email": "new_email", "points": 100})
#       5 )
#
# AttributeError: module 'firebase_admin.firestore' has no attribute 'fieldValue'

# %%
print(fake_people)
# Out:
# [{'person_name': 'Jeremy bonin', 'person_referrals': 1, 'person_points': 168.32874609946802}, {'person_name': 'Joyce', 'person_referrals': 10, 'person_points': 1064.5345045503498}, {'person_name': 'RIcardo whicker', 'person_referrals': 14, 'person_points': 1481.5790459340094}, {'person_name': 'Tiffanie', 'person_referrals': 10, 'person_points': 1062.7410076880824}, {'person_name': 'Marina', 'person_referrals': 10, 'person_points': 1068.2544470738578}, {'person_name': 'ELvira', 'person_referrals': 5, 'person_points': 567.260450263808}, {'person_name': 'Martina', 'person_referrals': 1, 'person_points': 168.7578690338987}, {'person_name': 'Raymond estrada', 'person_referrals': 2, 'person_points': 278.5934153144992}, {'person_name': 'Aaron Hudson', 'person_referrals': 12, 'person_points': 1270.8159576233327}, {'person_name': 'Emanuel seeger', 'person_referrals': 1, 'person_points': 164.40216619414701}, {'person_name': 'Rafael Morton', 'person_referrals': 5, 'person_points': 576.8811629265201}, {'person_name': 'Josephine', 'person_referrals': 8, 'person_points': 857.4993507629081}, {'person_name': 'Melodie', 'person_referrals': 6, 'person_points': 674.9888899651554}, {'person_name': 'Andy', 'person_referrals': 0, 'person_points': 70.9977273256421}, {'person_name': 'Matthew Gilmore', 'person_referrals': 13, 'person_points': 1375.128353561141}, {'person_name': 'Ted', 'person_referrals': 14, 'person_points': 1474.2810882004148}, {'person_name': 'LorinDa', 'person_referrals': 0, 'person_points': 75.73439036390468}, {'person_name': 'Renee jacobs', 'person_referrals': 9, 'person_points': 954.8881869861048}, {'person_name': 'LloyD', 'person_referrals': 9, 'person_points': 962.2672015601344}, {'person_name': 'Kristin zelinsky', 'person_referrals': 6, 'person_points': 678.3708968004829}, {'person_name': 'Marie Brown', 'person_referrals': 0, 'person_points': 58.71899758821455}, {'person_name': 'Elsa', 'person_referrals': 0, 'person_points': 62.50133775583137}, {'person_name': 'KAren', 'person_referrals': 12, 'person_points': 1269.4468464810107}, {'person_name': 'Karen LaM', 'person_referrals': 1, 'person_points': 180.04618616220384}, {'person_name': 'JohN martin', 'person_referrals': 0, 'person_points': 78.27917721558393}, {'person_name': 'John SeitZ', 'person_referrals': 7, 'person_points': 757.8402969290241}, {'person_name': 'Diane', 'person_referrals': 6, 'person_points': 677.0695474816342}, {'person_name': 'Kevin joseph', 'person_referrals': 9, 'person_points': 972.4596353998307}, {'person_name': 'Horace Baker', 'person_referrals': 6, 'person_points': 666.8146928473642}, {'person_name': 'Brady', 'person_referrals': 12, 'person_points': 1280.1825392506457}, {'person_name': 'Donna blake', 'person_referrals': 11, 'person_points': 1171.8823258724724}, {'person_name': 'Jason cameron', 'person_referrals': 0, 'person_points': 76.82903021091919}, {'person_name': 'Asha Rector', 'person_referrals': 5, 'person_points': 577.5709353140057}, {'person_name': 'ElizabEth', 'person_referrals': 11, 'person_points': 1175.3234259888384}, {'person_name': 'Thomas baptiste', 'person_referrals': 0, 'person_points': 59.50892800106271}, {'person_name': 'JaMes yates', 'person_referrals': 5, 'person_points': 562.7159223615945}, {'person_name': 'StephEn keller', 'person_referrals': 0, 'person_points': 70.26793735931881}, {'person_name': 'Margaret milton', 'person_referrals': 1, 'person_points': 153.97033793934872}, {'person_name': 'GabRiel', 'person_referrals': 6, 'person_points': 676.7636241957406}, {'person_name': 'Rosa rudolph', 'person_referrals': 14, 'person_points': 1478.021586500187}, {'person_name': 'THomas richardson', 'person_referrals': 0, 'person_points': 76.80708655547838}, {'person_name': 'Thomas Rodriquez', 'person_referrals': 1, 'person_points': 162.71778804012501}, {'person_name': 'Mack cooper', 'person_referrals': 10, 'person_points': 1062.1273167864563}, {'person_name': 'ReNee', 'person_referrals': 9, 'person_points': 970.336204669741}, {'person_na ...

# %%
random.randint(0,10)
# Out:
# 9
